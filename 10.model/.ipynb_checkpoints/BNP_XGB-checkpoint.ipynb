# %% [markdown]
# # Data Survey & XGB
# BNP Paribasのデータを読み込みいろいろやる

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import operator
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc,recall_score,precision_score

import xgboost as xgb
from xgboost import plot_importance

# %%
sns.set_style('whitegrid')
# %matplotlib inline

pd.set_option("display.max_colwidth", 200)
pd.set_option("display.max_columns", 200)

# %%
# jupyterの幅を自動調整
#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ## データ読み込み・基本情報

# %%
d = pd.read_csv('../01.data/train.csv')

# %%
# 基本情報を表示
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114321 entries, 0 to 114320
# Columns: 133 entries, ID to v131
# dtypes: float64(108), int64(6), object(19)
# memory usage: 116.0+ MB

# %%
# 行数とカラム数をカウント
rows = d.shape[0]
columns = d.shape[1]
print("The train dataset contains {0} rows and {1} columns".format(rows, columns))
# Out:
# The train dataset contains 114321 rows and 133 columns

# %%
d.describe()
# Out:
#                   ID         target            v1            v2            v4  \
# count  114321.000000  114321.000000  6.448900e+04  6.452500e+04  6.452500e+04
# mean   114228.928228       0.761199  1.630686e+00  7.464411e+00  4.145098e+00
# std     65934.487362       0.426353  1.082813e+00  2.961676e+00  1.148263e+00
# min         3.000000       0.000000 -9.996497e-07 -9.817614e-07 -6.475929e-07
# 25%     57280.000000       1.000000  9.135798e-01  5.316428e+00  3.487398e+00
# 50%    114189.000000       1.000000  1.469550e+00  7.023803e+00  4.205991e+00
# 75%    171206.000000       1.000000  2.136128e+00  9.465497e+00  4.833250e+00
# max    228713.000000       1.000000  2.000000e+01  2.000000e+01  2.000000e+01
#
#                  v5            v6            v7            v8            v9  \
# count  6.569700e+04  6.448900e+04  6.448900e+04  6.570200e+04  6.447000e+04
# mean   8.742359e+00  2.436402e+00  2.483921e+00  1.496569e+00  9.031859e+00
# std    2.036018e+00  5.999653e-01  5.894485e-01  2.783003e+00  1.930262e+00
# min   -5.287068e-07 -9.055091e-07 -9.468765e-07 -7.783778e-07 -9.828757e-07
# 25%    7.605918e+00  2.065064e+00  2.101477e+00  8.658986e-02  7.853659e+00
# 50%    8.670867e+00  2.412790e+00  2.452166e+00  3.860317e-01  9.059582e+00
# 75%    9.771353e+00  2.775285e+00  2.834285e+00  1.625246e+00  1.023256e+01
# max    2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01
#
#                 v10           v11           v12           v13           v14  \
# count  1.142370e+05  6.448500e+04  1.142350e+05  6.448900e+04  1.143170e+05
# mean   1.883046e+00  1.544741e+01  6.881304e+00  3.798396e+00  1.209428e+01
# std    1.393979e+00  7.900790e-01  9.244945e-01  1.175892e+00  1.443947e+00
# min   -9.875317e-07 -1.459062e-07  5.143224e-07 -8.464889e-07 -9.738831e-07
# 25%    1.050328e+00  1.500000e+01  6.322471e+00  3.067998e+00  1.125602e+01
# 50%    1.312910e+00  1.549595e+01  6.612969e+00  3.591081e+00  1.196783e+01
# 75%    2.100657e+00  1.595000e+01  7.019983e+00  4.289486e+00  1.271577e+01
# max    1.853392e+01  2.000000e+01  1.871055e+01  2.000000e+01  2.000000e+01
#
#                 v15           v16           v17           v18           v19  \
# 25%    5.763345e+00  6.981627e+00  3.150087e-01  7.758620e-01  1.786965e+00
# 50%    8.070175e+00  8.136964e+00  1.461561e+00  1.144708e+00  2.436195e+00
# 75%    1.050322e+01  9.565218e+00  4.166049e+00  1.647220e+00  3.379175e+00
# max    2.000000e+01  2.000000e+01  2.000000e+01  1.039427e+01  2.000000e+01
#
#                v122          v123          v124          v126          v127  \
# count  6.447000e+04  63643.000000  6.570200e+04  6.448900e+04  6.448900e+04
# mean   6.822439e+00      3.549938  9.198120e-01  1.672658e+00  3.239542e+00
# std    1.795978e+00      2.604704  2.099407e+00  5.031683e-01  1.625988e+00
# min   -9.978497e-07      0.019139 -9.994953e-07 -9.564174e-07 -9.223798e-07
# 25%    5.647712e+00      1.963315  2.053777e-02  1.417600e+00  2.101900e+00
# 50%    6.749117e+00      2.739239  1.398639e-01  1.614802e+00  2.963620e+00
# 75%    7.911392e+00      4.075361  8.718333e-01  1.843886e+00  4.108146e+00
# max    2.000000e+01     19.686069  2.000000e+01  1.563161e+01  2.000000e+01
#
#                v128           v129          v130          v131
# count  6.569700e+04  114321.000000  6.447800e+04  6.442600e+04
# mean   2.030373e+00       0.310144  1.925763e+00  1.739389e+00
# std    1.074232e+00       0.693262  1.264497e+00  1.134702e+00
# min    8.197812e-07       0.000000 -9.901257e-07 -9.999134e-07
# 25%    1.393830e+00       0.000000  1.106172e+00  1.012658e+00
# 50%    1.798436e+00       0.000000  1.560138e+00  1.589403e+00
# 75%    2.390158e+00       0.000000  2.332425e+00  2.261905e+00
# max    2.000000e+01      11.000000  2.000000e+01  2.000000e+01

# %%
d.groupby('v24').agg({'ID': 'count'})
# Out:
#         ID
# v24
# A     3789
# B     8150
# C    20872
# D    26333
# E    55177

# %%
# カテゴリ変数のユニーク数をカウント
for f in d.columns: 
    if d[f].dtype=='object': 
        print(f)
        print(d[f].nunique())
        print('----------------------')
        print(' ')
# Out:
# v3
# 3
# ----------------------
#
# v22
# 18210
# ----------------------
#
# v24
# 5
# ----------------------
#
# v30
# 7
# ----------------------
#
# v31
# 3
# ----------------------
#
# v47
# 10
# ----------------------
#
# v52
# 12
# ----------------------
#
# v56
# 122
# ----------------------
#
# v66
# 3
# ----------------------
#
# v71
# 9
# ----------------------
#
# v74
# 3
# ----------------------
#
# v75
# 4
# ----------------------
#
# v79
# 18
# ----------------------
#
# v91
# 7
# ----------------------
#
# v107
# 7
# ----------------------
#
# v110
# 3
# ----------------------
#
# v112
# 22
# ----------------------
#
# v113
# 36
# ----------------------
#
# v125
# 90
# ----------------------

# %%
# most of the claims were suitable for an accelerated approval
sns.countplot(x="target", data=d)

# %% [markdown]
# # Null可視化

# %%
msno.matrix(df=d.iloc[0:26,2:132], 
            figsize=(18, 6), 
            color=(0.42, 0.1, 0.05))

# %% [markdown]
# # 変数間の相関を可視化

# %%
# 目的変数と数字型の変数を指定
numerical_columns = ['target',	'v1',	'v2',	'v4',	'v5',	'v6',	'v7',	'v8',	'v9',	'v10',	'v11',	'v12',	'v13',	'v14',	'v15',	'v16',	'v17',
           'v18',	'v19',	'v20',	'v21',	'v23',	'v25',	'v26',	'v27',	'v28',	'v29',	'v32',	'v33',	'v34',	'v35',	'v36',	'v37',	'v38',	'v39',
           'v40',	'v41',	'v42',	'v43',	'v44',	'v45',	'v46',	'v48',	'v49',	'v50',	'v51',	'v53',	'v54',	'v55',	'v57',	'v58',	'v59',	'v60',	
           'v61',	'v62',	'v63',	'v64',	'v65',	'v67',	'v68',	'v69',	'v70',	'v72',	'v73',	'v76',	'v77',	'v78',	'v80',	'v81',	'v82',	'v83',	
           'v84',	'v85',	'v86',	'v87',	'v88',	'v89',	'v90',	'v92',	'v93',	'v94',	'v95',	'v96',	'v97',	'v98',	'v99',	'v100',	'v101',	'v102',	
           'v103',	'v104',	'v105',	'v106',	'v108',	'v109',	'v111',	'v114',	'v115',	'v116',	'v117',	'v118',	'v119',	'v120',	'v121',	'v122',	
           'v123',	'v124',	'v126',	'v127',	'v128',	'v129',	'v130',	'v131']
categorical_colums = ['v3','v22','v24','v30','v31','v47','v52','v56','v66','v71','v74','v75','v79','v107','v110','v112','v113','v125']

explanatory_colums = ['v1',	'v2',	'v3',	'v4',	'v5',	'v6',	'v7',	'v8',	'v9',	'v10',	'v11',	'v12',	'v13',	'v14',	'v15',	'v16',	'v17',	
                      'v18',	'v19',	'v20',	'v21',	'v22',	'v23',	'v24',	'v25',	'v26',	'v27',	'v28',	'v29',	'v30',	'v31',	'v32',	'v33',	'v34',	
                      'v35',	'v36',	'v37',	'v38',	'v39',	'v40',	'v41',	'v42',	'v43',	'v44',	'v45',	'v46',	'v47',	'v48',	'v49',	'v50',	'v51',	
                      'v52',	'v53',	'v54',	'v55',	'v56',	'v57',	'v58',	'v59',	'v60',	'v61',	'v62',	'v63',	'v64',	'v65',	'v66',	'v67',	'v68',	
                      'v69',	'v70',	'v71',	'v72',	'v73',	'v74',	'v75',	'v76',	'v77',	'v78',	'v79',	'v80',	'v81',	'v82',	'v83',	'v84',	'v85',	
                      'v86',	'v87',	'v88',	'v89',	'v90',	'v91',	'v92',	'v93',	'v94',	'v95',	'v96',	'v97',	'v98',	'v99',	'v100',	'v101',	'v102',	
                      'v103',	'v104',	'v105',	'v106',	'v107',	'v108',	'v109',	'v110',	'v111',	'v112',	'v113',	'v114',	'v115',	'v116',	'v117',	'v118',	
                      'v119',	'v120',	'v121',	'v122',	'v123',	'v124',	'v125',	'v126',	'v127',	'v128',	'v129',	'v130',	'v131',]
target_column      = 'target'

# %%
sns.set(style="white")
# Compute the correlation matrix
corr = d[numerical_columns].corr()

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 20))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# ## XGBoost
# https://www.kaggle.com/insaff/xgboost
#
# - まだone-hotしていない
# - ROCとか描画しないといけない

# %%
# 変数マップを作成する
def create_feature_map(features):
    outfile = open('xgb.fmap', 'w')
    i = 0
    for feat in features:
        outfile.write('{0}\t{1}\tq\n'.format(i, feat))
        i = i + 1

    outfile.close()

# %%
d_drop_ID = d.drop(['ID'], axis=1) # IDを削除
target = d['target'] # 正解をリストに格納しておく

# %%
# カテゴリ変数を数値に変換
from sklearn import preprocessing 
for f in d_drop_ID.columns: 
    if d[f].dtype=='object': 
        lbl = preprocessing.LabelEncoder() 
        lbl.fit(list(d_drop_ID[f].values)) 
        d_drop_ID[f] = lbl.transform(list(d_drop_ID[f].values))

# %%
# array型に変換
d_array = np.array(d_drop_ID)
d_array = d_array.astype(float)

# %%
# Split the Learning Set
X_train, X_valid, y_train, y_valid  = train_test_split(d_array, target, test_size=0.3, random_state=1)

# %% [markdown]
# ## fit関数を利用して学習するーー

# %%
# parameters setting
# n_estimators and early_stopping_rounds should be increased
model = xgb.XGBClassifier(missing=np.nan, 
                        max_depth=7, 
                        n_estimators=300, 
                        learning_rate=0.05, 
                        subsample=1, 
                        colsample_bytree=0.9, 
                        seed=2100,
                        objective= 'binary:logistic')

# %%
# fitting
model.fit(X_train, 
          y_train,  
          early_stopping_rounds=35,  
          eval_metric="logloss", 
          eval_set=[(X_valid, y_valid)] # dataset to use validation for early-stopping 
         )
# Out:
# [0]	validation_0-logloss:0.644401
# Will train until validation_0-logloss hasn't improved in 35 rounds.
# [1]	validation_0-logloss:0.600292
# [2]	validation_0-logloss:0.560189
# [3]	validation_0-logloss:0.523577
# [4]	validation_0-logloss:0.490033
# [5]	validation_0-logloss:0.459203
# [6]	validation_0-logloss:0.430788
# [7]	validation_0-logloss:0.404536
# [8]	validation_0-logloss:0.380226
# [9]	validation_0-logloss:0.357671
# [10]	validation_0-logloss:0.349743
# [11]	validation_0-logloss:0.342453
# [12]	validation_0-logloss:0.322537
# [13]	validation_0-logloss:0.303975
# [14]	validation_0-logloss:0.286652
# [15]	validation_0-logloss:0.270463
# [16]	validation_0-logloss:0.255318
# [17]	validation_0-logloss:0.241134
# [18]	validation_0-logloss:0.227837
# [19]	validation_0-logloss:0.215359
# [20]	validation_0-logloss:0.203641
# [21]	validation_0-logloss:0.192627
# [22]	validation_0-logloss:0.182269
# [23]	validation_0-logloss:0.172519
# [24]	validation_0-logloss:0.163338
# [25]	validation_0-logloss:0.154686
# [26]	validation_0-logloss:0.146528
# [27]	validation_0-logloss:0.138833
# [28]	validation_0-logloss:0.136411
# [29]	validation_0-logloss:0.129283
# [30]	validation_0-logloss:0.122553
# [31]	validation_0-logloss:0.116195
# [32]	validation_0-logloss:0.11448
# [33]	validation_0-logloss:0.108564
# [34]	validation_0-logloss:0.102971
# [35]	validation_0-logloss:0.097681
# [36]	validation_0-logloss:0.092677
# [37]	validation_0-logloss:0.087941
# [38]	validation_0-logloss:0.083458
# [39]	validation_0-logloss:0.08219
# [40]	validation_0-logloss:0.081015
# [41]	validation_0-logloss:0.076898
# [42]	validation_0-logloss:0.072999
# [43]	validation_0-logloss:0.069304
# [44]	validation_0-logloss:0.065804
# [45]	validation_0-logloss:0.062486
# [46]	validation_0-logloss:0.059341
# [47]	validation_0-logloss:0.056359
# [48]	validation_0-logloss:0.053532
# [49]	validation_0-logloss:0.05085
# [50]	validation_0-logloss:0.050182
# [51]	validation_0-logloss:0.047672
# [52]	validation_0-logloss:0.04529
# [53]	validation_0-logloss:0.044733
# [54]	validation_0-logloss:0.042501
# [55]	validation_0-logloss:0.040384
# [56]	validation_0-logloss:0.038374
# [57]	validation_0-logloss:0.036466
# [58]	validation_0-logloss:0.034655
# [59]	validation_0-logloss:0.032936
# [60]	validation_0-logloss:0.031303
# [61]	validation_0-logloss:0.029753
# [62]	validation_0-logloss:0.028281
# [63]	validation_0-logloss:0.026882
# [64]	validation_0-logloss:0.025554
# [65]	validation_0-logloss:0.025265
# [66]	validation_0-logloss:0.024018
# [67]	validation_0-logloss:0.022833
# [68]	validation_0-logloss:0.021708
# [69]	validation_0-logloss:0.020638
# [70]	validation_0-logloss:0.019622
# [71]	validation_0-logloss:0.018656
# [72]	validation_0-logloss:0.017739
# [73]	validation_0-logloss:0.016867
# [74]	validation_0-logloss:0.016038
# [75]	validation_0-logloss:0.015251
# [76]	validation_0-logloss:0.015092
# [77]	validation_0-logloss:0.014351
# [78]	validation_0-logloss:0.013647
# [79]	validation_0-logloss:0.012978
# [80]	validation_0-logloss:0.012853
# [81]	validation_0-logloss:0.012223
# [82]	validation_0-logloss:0.011624
# [83]	validation_0-logloss:0.011055
# [84]	validation_0-logloss:0.010955
# [85]	validation_0-logloss:0.010419
# [86]	validation_0-logloss:0.009909
# [87]	validation_0-logloss:0.009424
# [88]	validation_0-logloss:0.008964
# [89]	validation_0-logloss:0.008526
# [90]	validation_0-logloss:0.008109
# [91]	validation_0-logloss:0.007713
# [92]	validation_0-logloss:0.007337
# [93]	validation_0-logloss:0.006979
# [94]	validation_0-logloss:0.006638
# [95]	validation_0-logloss:0.006315
# [96]	validation_0-logloss:0.006263
# [97]	validation_0-logloss:0.005958
# [98]	validation_0-logloss:0.005667
# [99]	validation_0-logloss:0.005391
# [100]	validation_0-logloss:0.005129
# [101]	validation_0-logloss:0.004879
# [102]	validation_0-logloss:0.004642
# [103]	validation_0-logloss:0.004416
# [104]	validation_0-logloss:0.004387
# [105]	validation_0-logloss:0.004173
# [106]	validation_0-logloss:0.003971
# [107]	validation_0-logloss:0.003778
# [108]	validation_0-logloss:0.003594
# [109]	validation_0-logloss:0.003571
# [110]	validation_0-logloss:0.003397
# [111]	validation_0-logloss:0.003233
# [112]	validation_0-logloss:0.003076
# [113]	validation_0-logloss:0.002927
# [114]	validation_0-logloss:0.002785
# [115]	validation_0-logloss:0.00265
# [116]	validation_0-logloss:0.002522
# [117]	validation_0-logloss:0.0024
# [118]	validation_0-logloss:0.002284
# [119]	validation_0-logloss:0.002174
# [120]	validation_0-logloss:0.002069
# [121]	validation_0-logloss:0.001969
# [122]	validation_0-logloss:0.001874
# [123]	validation_0-logloss:0.001784
# [124]	validation_0-logloss:0.001773
# [125]	validation_0-logloss:0.001687
# [126]	validation_0-logloss:0.001606
# [127]	validation_0-logloss:0.001529
# [128]	validation_0-logloss:0.001456
# [129]	validation_0-logloss:0.001386
# [130]	validation_0-logloss:0.001319
# [131]	validation_0-logloss:0.001312
# [132]	validation_0-logloss:0.001249
# [133]	validation_0-logloss:0.001243
# [134]	validation_0-logloss:0.001183
# [135]	validation_0-logloss:0.001178
# [136]	validation_0-logloss:0.001121
# [137]	validation_0-logloss:0.001117
# [138]	validation_0-logloss:0.001063
# [139]	validation_0-logloss:0.001013
# [140]	validation_0-logloss:0.000964
# [141]	validation_0-logloss:0.000919
# [142]	validation_0-logloss:0.000875
# [143]	validation_0-logloss:0.000833
# [144]	validation_0-logloss:0.000794
# [145]	validation_0-logloss:0.000756
# [146]	validation_0-logloss:0.000721
# [147]	validation_0-logloss:0.000687
# [148]	validation_0-logloss:0.000684
# [149]	validation_0-logloss:0.000652
# [150]	validation_0-logloss:0.000621
# [151]	validation_0-logloss:0.000592
# [152]	validation_0-logloss:0.000564
# [153]	validation_0-logloss:0.000562
# [154]	validation_0-logloss:0.000536
# [155]	validation_0-logloss:0.000511
# [156]	validation_0-logloss:0.000487
# [157]	validation_0-logloss:0.000465
# [158]	validation_0-logloss:0.000443
# [159]	validation_0-logloss:0.000423
# [160]	validation_0-logloss:0.000403
# [161]	validation_0-logloss:0.000385
# [162]	validation_0-logloss:0.000367
# [163]	validation_0-logloss:0.00035
# [164]	validation_0-logloss:0.000334
# [165]	validation_0-logloss:0.000319
# [166]	validation_0-logloss:0.000305
# [167]	validation_0-logloss:0.000291
# [168]	validation_0-logloss:0.000278
# [169]	validation_0-logloss:0.000277
# [170]	validation_0-logloss:0.000265
# [171]	validation_0-logloss:0.000253
# [172]	validation_0-logloss:0.000242
# [173]	validation_0-logloss:0.000241
# [174]	validation_0-logloss:0.00023
# [175]	validation_0-logloss:0.00023
# [176]	validation_0-logloss:0.00022
# [177]	validation_0-logloss:0.00021
# [178]	validation_0-logloss:0.000201
# [179]	validation_0-logloss:0.000192
# [180]	validation_0-logloss:0.000184
# [181]	validation_0-logloss:0.000176
# [182]	validation_0-logloss:0.000168
# [183]	validation_0-logloss:0.000161
# [184]	validation_0-logloss:0.000154
# [185]	validation_0-logloss:0.000148
# [186]	validation_0-logloss:0.000142
# [187]	validation_0-logloss:0.000136
# [188]	validation_0-logloss:0.00013
# [189]	validation_0-logloss:0.000125
# [190]	validation_0-logloss:0.00012
# [191]	validation_0-logloss:0.000115
# [192]	validation_0-logloss:0.00011
# [193]	validation_0-logloss:0.000106
# [194]	validation_0-logloss:0.000102
# [195]	validation_0-logloss:9.8e-05
# [196]	validation_0-logloss:9.4e-05
# [197]	validation_0-logloss:9e-05
# [198]	validation_0-logloss:8.7e-05
# [199]	validation_0-logloss:8.3e-05
# [200]	validation_0-logloss:8e-05
# [201]	validation_0-logloss:7.7e-05
# [202]	validation_0-logloss:7.4e-05
# [203]	validation_0-logloss:7.2e-05
# [204]	validation_0-logloss:6.9e-05
# [205]	validation_0-logloss:6.7e-05
# [206]	validation_0-logloss:6.4e-05
# [207]	validation_0-logloss:6.2e-05
# [208]	validation_0-logloss:6e-05
# [209]	validation_0-logloss:5.8e-05
# [210]	validation_0-logloss:5.6e-05
# [211]	validation_0-logloss:5.4e-05
# [212]	validation_0-logloss:5.2e-05
# [213]	validation_0-logloss:5e-05
# [214]	validation_0-logloss:4.9e-05
# [215]	validation_0-logloss:4.7e-05
# [216]	validation_0-logloss:4.6e-05
# [217]	validation_0-logloss:4.4e-05
# [218]	validation_0-logloss:4.3e-05
# [219]	validation_0-logloss:4.1e-05
# [220]	validation_0-logloss:4.1e-05
# [221]	validation_0-logloss:4e-05
# [222]	validation_0-logloss:3.9e-05
# [223]	validation_0-logloss:3.8e-05
# [224]	validation_0-logloss:3.7e-05
# [225]	validation_0-logloss:3.6e-05
# [226]	validation_0-logloss:3.4e-05
# [227]	validation_0-logloss:3.4e-05
# [228]	validation_0-logloss:3.3e-05
# [229]	validation_0-logloss:3.2e-05
# [230]	validation_0-logloss:3.1e-05
# [231]	validation_0-logloss:3e-05
# [232]	validation_0-logloss:2.9e-05
# [233]	validation_0-logloss:2.8e-05
# [234]	validation_0-logloss:2.8e-05
# [235]	validation_0-logloss:2.8e-05
# [236]	validation_0-logloss:2.8e-05
# [237]	validation_0-logloss:2.8e-05
# [238]	validation_0-logloss:2.8e-05
# [239]	validation_0-logloss:2.8e-05
# [240]	validation_0-logloss:2.8e-05
# [241]	validation_0-logloss:2.7e-05
# [242]	validation_0-logloss:2.7e-05
# [243]	validation_0-logloss:2.7e-05
# [244]	validation_0-logloss:2.7e-05
# [245]	validation_0-logloss:2.7e-05
# [246]	validation_0-logloss:2.7e-05
# [247]	validation_0-logloss:2.7e-05
# [248]	validation_0-logloss:2.7e-05
# [249]	validation_0-logloss:2.7e-05
# [250]	validation_0-logloss:2.7e-05
# [251]	validation_0-logloss:2.7e-05
# [252]	validation_0-logloss:2.7e-05
# [253]	validation_0-logloss:2.7e-05
# [254]	validation_0-logloss:2.7e-05
# [255]	validation_0-logloss:2.7e-05
# [256]	validation_0-logloss:2.7e-05
# [257]	validation_0-logloss:2.6e-05
# [258]	validation_0-logloss:2.6e-05
# [259]	validation_0-logloss:2.6e-05
# [260]	validation_0-logloss:2.6e-05
# [261]	validation_0-logloss:2.6e-05
# [262]	validation_0-logloss:2.6e-05
# [263]	validation_0-logloss:2.6e-05
# [264]	validation_0-logloss:2.6e-05
# [265]	validation_0-logloss:2.6e-05
# [266]	validation_0-logloss:2.6e-05
# [267]	validation_0-logloss:2.6e-05
# [268]	validation_0-logloss:2.6e-05
# [269]	validation_0-logloss:2.6e-05
# [270]	validation_0-logloss:2.6e-05
# [271]	validation_0-logloss:2.6e-05
# [272]	validation_0-logloss:2.6e-05
# [273]	validation_0-logloss:2.6e-05
# [274]	validation_0-logloss:2.6e-05
# [275]	validation_0-logloss:2.6e-05
# [276]	validation_0-logloss:2.6e-05
# [277]	validation_0-logloss:2.6e-05
# [278]	validation_0-logloss:2.6e-05
# [279]	validation_0-logloss:2.6e-05
# [280]	validation_0-logloss:2.6e-05
# [281]	validation_0-logloss:2.5e-05
# [282]	validation_0-logloss:2.5e-05
# [283]	validation_0-logloss:2.5e-05
# [284]	validation_0-logloss:2.5e-05
# [285]	validation_0-logloss:2.5e-05
# [286]	validation_0-logloss:2.5e-05
# [287]	validation_0-logloss:2.5e-05
# [288]	validation_0-logloss:2.5e-05
# [289]	validation_0-logloss:2.5e-05
# [290]	validation_0-logloss:2.5e-05
# [291]	validation_0-logloss:2.5e-05
# [292]	validation_0-logloss:2.5e-05
# [293]	validation_0-logloss:2.5e-05
# [294]	validation_0-logloss:2.5e-05
# [295]	validation_0-logloss:2.5e-05
# [296]	validation_0-logloss:2.5e-05
# [297]	validation_0-logloss:2.5e-05
# [298]	validation_0-logloss:2.5e-05
# [299]	validation_0-logloss:2.5e-05
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_delta_step=0,
#        max_depth=7, min_child_weight=1, missing=None, n_estimators=300,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=2100,
#        silent=True, subsample=1)

# %%
# save model to file
pickle.dump(model, open("./02.pickle/model.pickle", "wb"))

# %%
# load model from file
loaded_model = pickle.load( open('./02.pickle/model.pickle', 'rb'))

# %% [markdown]
# ## 重要変数

# %%
# weight : 
# gain :
# cover :
importance = model.get_booster().get_score(fmap='01.fmap/xgb.fmap', importance_type='weight')
importance = sorted(importance.items(), key=operator.itemgetter(1))

# %%
# dataframe化
df_importance = pd.DataFrame(importance, columns=['features', 'score'])
df_importance['score'] = df_importance['score'] / df_importance['score'].sum()

# %%
df_importance.tail(10)
# Out:
#     features     score
# 116      v11  0.024332
# 117     v115  0.024332
# 118      v25  0.026113
# 119      v22  0.026706
# 120      v57  0.027893
# 121      v48  0.037982
# 122      v41  0.037982
# 123      v67  0.068843
# 124       v1  0.125816
# 125      v51  0.167953

# %%
# 重要度を可視化
plt.figure()
#df_importance.plot()
df_importance.plot(kind='barh', x='features', y='score', legend=False, figsize=(25, 25))
plt.title('XGBoost Feature Importance')
plt.xlabel('relative importance')
plt.gcf().savefig('03.importance/feature_importance_xgb.png')

# %% [markdown]
# ## 予測

# %%
# 1に分類される確率が配列の2つ目に格納される
pred = model.predict_proba(X_valid)[:, 1]

# %%
pred
# Out:
# array([4.4031869e-05, 9.9998212e-01, 9.9998534e-01, ..., 9.9998081e-01,
#        3.4450739e-05, 9.9998236e-01], dtype=float32)

# %%
y_valid.values
# Out:
# array([0, 1, 1, ..., 1, 0, 1], dtype=int64)

# %%
from sklearn import metrics as mtr

# %%
fpr, tpr, thresholds = mtr.roc_curve(y_valid.values, pred)

# %%
thresholds
# Out:
# array([9.99989867e-01, 9.99989748e-01, 9.99989629e-01, 9.99989510e-01,
#        9.99989390e-01, 9.99989271e-01, 9.99989152e-01, 9.99989033e-01,
#        9.99988914e-01, 9.99988794e-01, 9.99988675e-01, 9.99988556e-01,
#        9.99988437e-01, 9.99988317e-01, 9.99988198e-01, 9.99988079e-01,
#        9.99987960e-01, 9.99987841e-01, 9.99987721e-01, 9.99987602e-01,
#        9.99987483e-01, 9.99987364e-01, 9.99987245e-01, 9.99987125e-01,
#        1.90049068e-05, 1.89912298e-05, 1.89900511e-05, 1.89456441e-05,
#        1.89430066e-05, 1.89249859e-05, 1.89234524e-05, 1.88667800e-05,
#        1.88638296e-05, 1.88045396e-05, 1.87967580e-05, 1.87883543e-05,
#        1.87863461e-05, 1.87572732e-05, 1.87521400e-05, 1.87426831e-05,
#        1.87414680e-05, 1.87275855e-05, 1.87229434e-05, 1.87206206e-05,
#        1.87005298e-05, 1.87000660e-05, 1.86884245e-05, 1.86682955e-05,
#        1.86635607e-05, 1.86188881e-05, 1.86081288e-05, 1.86056823e-05,
#        1.85975023e-05, 1.85849676e-05, 1.85659064e-05, 1.85582248e-05,
#        1.85462814e-05, 1.85428871e-05, 1.85424633e-05, 1.85386070e-05,
#        1.85177923e-05, 1.85036351e-05, 1.85013068e-05, 1.84840756e-05,
#        1.84014298e-05, 1.83938155e-05, 1.83397096e-05], dtype=float32)

# %%
plt.plot(fpr, tpr)
plt.title("ROC curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()

# %% [markdown]
# ## Train & 重要変数の可視化
# なんか上のほうでfit関数使っているが、
# 重要変数を取り出すget_fscore関数が実装されていない？ためこっちでやってみる

# %%
# 説明変数のリストを作成
features = list(d_drop_ID.columns[1:])

# %%
# 説明変数をマッピングするためのファイルを作成
create_feature_map(features)

# %%
# モデルのハイパーパラメータを設定
xgb_params = {"objective": "binary:logistic", 
              "missing": np.nan,
              "max_depth": 7,
              "n_estimators": 300, 
              "learning_rate":0.05,
              "subsample":0.9,
              "colsample_bytree":0.9,
              "seed": 2100
             }
num_rounds = 1000

# %%
# train関数に投入するマトリックスを作成
dtrain = xgb.DMatrix(X_train, y_train)

# %%
# モデル構築
gbdt = xgb.train(xgb_params, 
                 dtrain = dtrain, 
                 num_boost_round =num_rounds,
                 evals=[(X_valid, y_valid)],
                 early_stopping_rounds=50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-ed367d899767> in <module>()
#       4                  num_boost_round =num_rounds,
#       5                  evals=[(X_valid, y_valid)],
# ----> 6                  early_stopping_rounds=50)
#
# /usr/local/opt/pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/xgboost-0.6-py3.6.egg/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# /usr/local/opt/pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/xgboost-0.6-py3.6.egg/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      30             params += [('eval_metric', eval_metric)]
#      31
# ---> 32     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#      33     nboost = 0
#      34     num_parallel_tree = 1
#
# /usr/local/opt/pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/xgboost-0.6-py3.6.egg/xgboost/core.py in __init__(self, params, cache, model_file)
#     720         for d in cache:
#     721             if not isinstance(d, DMatrix):
# --> 722                 raise TypeError('invalid cache item: {}'.format(type(d).__name__))
#     723             self._validate_features(d)
#     724
#
# TypeError: invalid cache item: ndarray

# %%
# 重要変数
importance = gbdt.get_fscore(fmap='xgb.fmap')
importance = sorted(importance.items(), key=operator.itemgetter(1))

# dataframe化
df_importance = pd.DataFrame(importance, columns=['features', 'score'])
df_importance['score'] = df_importance['score'] / df_importance['score'].sum()

# %%
df_importance.sort_values('score', ascending=False).head(10)
# Out:
#     features     score
# 114       v1  0.167860
# 113      v51  0.167064
# 112      v67  0.063644
# 111      v11  0.042164
# 110      v48  0.040573
# 109      v13  0.036595
# 108      v41  0.029435
# 107      v15  0.027049
# 106      v25  0.024662
# 105      v35  0.023866

# %%
plt.figure()
#df_importance.plot()
df_importance.plot(kind='barh', x='features', y='score', legend=False, figsize=(25, 25))
plt.title('XGBoost Feature Importance')
plt.xlabel('relative importance')
plt.gcf().savefig('feature_importance_xgb.png')

# %% [markdown]
# ## モデル結果の結果

# %%
model.feature_importances_
# Out:
# array([ 0.10794298,  0.00407332,  0.00203666,  0.        ,  0.00305499,
#         0.00560081,  0.00407332,  0.00509165,  0.00305499,  0.00203666,
#         0.04226069,  0.00254582,  0.03615071,  0.00101833,  0.01782077,
#         0.00203666,  0.00509165,  0.00152749,  0.00254582,  0.00407332,
#         0.00203666,  0.02494908,  0.00967413,  0.00560081,  0.02851324,
#         0.00203666,  0.00254582,  0.00152749,  0.00458248,  0.00050916,
#         0.00916497,  0.0101833 ,  0.00356415,  0.00050916,  0.02494908,
#         0.00152749,  0.00356415,  0.00509165,  0.00305499,  0.00458248,
#         0.03818737,  0.00203666,  0.00356415,  0.00050916,  0.00407332,
#         0.00661914,  0.00101833,  0.03105906,  0.00152749,  0.00152749,
#         0.14307536,  0.00661914,  0.00407332,  0.00407332,  0.00254582,
#         0.00407332,  0.02545825,  0.00356415,  0.00356415,  0.00356415,
#         0.00152749,  0.00101833,  0.00458248,  0.00203666,  0.00050916,
#         0.00407332,  0.06517312,  0.00101833,  0.00661914,  0.00305499,
#         0.00305499,  0.00509165,  0.00152749,  0.00254582,  0.00152749,
#         0.00050916,  0.00050916,  0.00050916,  0.00356415,  0.02087576,
#         0.00152749,  0.00101833,  0.00712831,  0.00305499,  0.00305499,
#         0.00152749,  0.00254582,  0.00407332,  0.00458248,  0.00407332,
#         0.00254582,  0.        ,  0.00305499,  0.00203666,  0.00458248,
#         0.00101833,  0.00050916,  0.00203666,  0.00560081,  0.00763747,
#         0.00509165,  0.00152749,  0.00560081,  0.00203666,  0.00050916,
#         0.        ,  0.00050916,  0.00101833,  0.00050916,  0.00305499,
#         0.00203666,  0.00101833,  0.00254582,  0.00814664,  0.0203666 ,
#         0.00254582,  0.00101833,  0.00407332,  0.00254582,  0.01069246,
#         0.00050916,  0.00050916,  0.00305499,  0.00203666,  0.01120163,
#         0.00458248,  0.00152749,  0.00407332,  0.00152749,  0.00661914,
#         0.00152749,  0.00610998], dtype=float32)

# %%
# 重要変数
fig, ax = plt.subplots(1, 1, figsize=(15, 30))
plot_importance(model, ax=ax)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-7c7b1e894802> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy = accuracy_score()
#
# TypeError: accuracy_score() missing 2 required positional arguments: 'y_true' and 'y_pred'

# %%
# scores
from  sklearn.metrics import log_loss
log_train = log_loss(y_fit, clf.predict_proba(X_fit)[:,1])
log_valid = log_loss(y_eval, clf.predict_proba(X_eval)[:,1])

# %%
log_train, log_valid
# Out:
# (2.5114758712634284e-05, 2.5316195133353126e-05)

# %%
xgb.to_graphviz(model, num_trees=2)

# %% [markdown]
# ## importance

# %% [markdown]
# ## ROC-curve

# %% [markdown]
# ## Calibrations
